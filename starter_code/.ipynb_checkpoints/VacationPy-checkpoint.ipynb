# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
city_df=pd.read_csv("../output_data/cities.csv")
city_df.head()
# Out:
#    City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  ostrovnoy           2      RU  1558378754        72  68.05
# 1        1  mahebourg          75      MU  1558378503        74 -20.41
# 2        2    qaanaaq          25      GL  1558378755        73  77.48
# 3        3     zhuhai           0      CN  1558378755        39  40.71
# 4        4  cape town          20      ZA  1558378755        76 -33.93
#
#       Lng  Max Temp  Wind Speed
# 0   39.51     37.50        7.16
# 1   57.70     78.80       11.41
# 2  -69.36     22.20        2.37
# 3  112.04     44.60        4.47
# 4   18.42     55.99        8.05

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
locations=city_df[["Lat", "Lng"]]

rating = city_df["Humidity"].astype(float)

# %%
# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=5,
                                 point_radius=1)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
city_df=city_df.loc[(city_df["Max Temp"]>68)]
city_df.count()
# Out:
# City_ID       241
# City          241
# Cloudiness    241
# Country       240
# Date          241
# Humidity      241
# Lat           241
# Lng           241
# Max Temp      241
# Wind Speed    241
# dtype: int64

# %%
city_df=city_df.loc[(city_df["Max Temp"]<70)]
city_df.count()
# Out:
# City_ID       2
# City          2
# Cloudiness    2
# Country       2
# Date          2
# Humidity      2
# Lat           2
# Lng           2
# Max Temp      2
# Wind Speed    2
# dtype: int64

# %%
city_df=city_df.loc[(city_df["Humidity"]<30)]
city_df.count()
# Out:
# City_ID       2
# City          2
# Cloudiness    2
# Country       2
# Date          2
# Humidity      2
# Lat           2
# Lng           2
# Max Temp      2
# Wind Speed    2
# dtype: int64

# %%
city_df.head()
# Out:
#      City_ID        City  Cloudiness Country        Date  Humidity    Lat  \
# 230      230  moses lake           1      US  1558378804        22  47.13
# 259      259        hami           0      CN  1558378834        11  42.84
#
#         Lng  Max Temp  Wind Speed
# 230 -119.28     69.80       13.87
# 259   93.51     69.72        6.20

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df=city_df
hotel_df
# Out:
#      City_ID        City  Cloudiness Country        Date  Humidity    Lat  \
# 230      230  moses lake           1      US  1558378804        22  47.13
# 259      259        hami           0      CN  1558378834        11  42.84
#
#         Lng  Max Temp  Wind Speed
# 230 -119.28     69.80       13.87
# 259   93.51     69.72        6.20

# %%
hotel_df["Hotel Name"]=""
hotel_df
# Out:
#      City_ID        City  Cloudiness Country        Date  Humidity    Lat  \
# 230      230  moses lake           1      US  1558378804        22  47.13
# 259      259        hami           0      CN  1558378834        11  42.84
#
#         Lng  Max Temp  Wind Speed Hotel Name
# 230 -119.28     69.80       13.87
# 259   93.51     69.72        6.20

# %%
# geocoordinates
target_city = "moses lake"
target_url = f'https://maps.googleapis.com/maps/api/geocode/json?address={target_city}&key={g_key}'
geo_data = requests.get(target_url).json()
lat = geo_data["results"][0]["geometry"]["location"]["lat"]
lng = geo_data["results"][0]["geometry"]["location"]["lng"]
target_coordinates = f"{lat}, {lng}"
target_radius = 5000
target_type = "Hotel"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": g_key
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
# convert response to json
places_data = response.json()

# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "ATtYBwJl-41_2GZ1_fXzz0ldjZj417ps3jnI691Equ0hWMDnpfdpb2e5esL0_Z1BAE7BPXqlO7XvcgT7w6LR8MY6YAvPfrpqu8ZxT48RIgcWEXIcjsL2zf5hckY1Czjuagjkyph5U1k4MCRwogxE96TFZ3rm88GEwREq1xHonpWIXTWqU6LipPUeghbZM9RTQFcUW_jq_quTaEbWNXEu8wYI1UcVKDrQl5nGIIxwnZmANHO8vGldLo86pYP2bl_XPJUny7P2uWM4OnkISFeT1hNjnXboJoBZ0EnMAZIiO-dmwTfBFcNX5HCuMZpdv95RTLAvpSnVFviI5__OMbQpMvN2kO6oCUixKf8zk5TTxDyF0JhM0SFk3DlKzvOVs8duxJ8W1pcZ9KB9JDnWrj_zMlaxeNVdl4tL9vQjEZtMUJcP7ntPhdjfMeVg2g",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 47.1301417,
#                     "lng": -119.2780771
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.20475589003185,
#                         "lng": -119.1876648852156
#                     },
#                     "southwest": {
#                         "lat": 47.05851197957438,
#                         "lng": -119.3478149898144
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png",
#             "name": "Moses Lake",
#             "photos": [
#                 {
#                     "height": 2988,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108138509120609085575\">Angie Gaitan</a>"
#                     ],
#                     "photo_reference": "ATtYBwIHQ38RORpFZgKbbmaPv3_IVOSUGk8RPmKB679mO4_Y9LP_IV2GNNSFwW2NsPZAgt43nUQ_J-Zhx1AbKWbzeKJia-YoyhxLK64yf1kWOXg5DRTnyjHCRJH_QKHZnxPxFHGFjPzJCC84JLasnxEKtW2uSYxAxpGp9n38qAXRUTPX0K5g",
#                     "width": 5312
#                 }
#             ],
#             "place_id": "ChIJ27vfjjU_mVQRJCDl7OXrUD8",
#             "reference": "ChIJ27vfjjU_mVQRJCDl7OXrUD8",
#             "scope": "GOOGLE",
#             "types": [
#                 "locality",
#                 "political"
#             ],
#             "vicinity": "Moses Lake"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.0999167,
#                     "lng": -119.246965
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.1012603302915,
#                         "lng": -119.2457515697085
#                     },
#                     "southwest": {
#                         "lat": 47.0985623697085,
#                         "lng": -119.2484495302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Ramada by Wyndham Moses Lake",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101544911404845099458\">Ramada by Wyndham Moses Lake</a>"
#                     ],
#                     "photo_reference": "ATtYBwLeSLzxC7nHrZCG5fbf6J4AaLzhPYiUbbdcp5PRcyQpJf9egM5hklbBWQAtgMxDm_ONOWMGZUgnG0iGT9HOF9BmS6FpqOVZ8KdbrQaK8mdCRqtejp79-2CxVOTB9ei40DeRLXwWlqnCjM7LRB4hNxGtxnTj4WjD--v7n2qEze_dfteo",
#                     "width": 3000
#                 }
#             ],
#             "place_id": "ChIJdQbtSS85mVQRBiy8_JL0tIA",
#             "plus_code": {
#                 "compound_code": "3QX3+X6 Moses Lake, WA, USA",
#                 "global_code": "85V23QX3+X6"
#             },
#             "rating": 4.2,
#             "reference": "ChIJdQbtSS85mVQRBiy8_JL0tIA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 316,
#             "vicinity": "1745 Kittelson Road, Moses Lake"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.12030240000001,
#                     "lng": -119.2670748
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.1216248802915,
#                         "lng": -119.2658602197085
#                     },
#                     "southwest": {
#                         "lat": 47.1189269197085,
#                         "lng": -119.2685581802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Sage N Sand Motel",
#             "photos": [
#                 {
#                     "height": 2512,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110327436163292682227\">Allie K</a>"
#                     ],
#                     "photo_reference": "ATtYBwIc8aYUjtXYdBIvPTaAweK2gTiaCnDhVegoznJY3RE9fmJ0kS8sSkCYKEmuQqHonggdLE1pjUb3FrotIYRsB9lU2tgpzmWS3RAtAa_6HY9q-TwvyUpJT0bnLHKqyO-QRhYMc7ypXk1toX22pZYUzurNdbgvMwl09PmqAa7WtwWVQK2R",
#                     "width": 3446
#                 }
#             ],
#             "place_id": "ChIJSTWT5sc4mVQRodkDws-mR7I",
#             "plus_code": {
#                 "compound_code": "4PCM+45 Moses Lake, WA, USA",
#                 "global_code": "85V24PCM+45"
#             },
#             "rating": 4.2,
#             "reference": "ChIJSTWT5sc4mVQRodkDws-mR7I",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 213,
#             "vicinity": "1011 South Pioneer Way, Moses Lake"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.14479799999999,
#                     "lng": -119.2756966
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.1462133802915,
#                         "lng": -119.2747676697085
#                     },
#                     "southwest": {
#                         "lat": 47.1435154197085,
#                         "lng": -119.2774656302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Ten Pin Inn & Suites",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3648,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108501351661033138130\">Ten Pin Inn &amp; Suites</a>"
#                     ],
#                     "photo_reference": "ATtYBwJg-Dmvn3TQHS6mZkXZp6kLvMKPXVKUbqgpQs7SVLHP5XDjUkCdp_5flHsWbHE61YGWnK_fk-evNSdt64L-HgxMCrRCPcZQZE9yrcHuh_wUVRS2paXlaylx3KF3sV2e7mEAZDudKE3bc_V0_PglC3IXnpqtflVzXrWOiXyP1qTjHpHj",
#                     "width": 5472
#                 }
#             ],
#             "place_id": "ChIJx3xft2BHmVQR4RHM8ptVxsE",
#             "plus_code": {
#                 "compound_code": "4PVF+WP Moses Lake, WA, USA",
#                 "global_code": "85V24PVF+WP"
#             },
#             "rating": 4.2,
#             "reference": "ChIJx3xft2BHmVQR4RHM8ptVxsE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 292,
#             "vicinity": "1157 North Stratford Road, Moses Lake"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.1034861,
#                     "lng": -119.3120768
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.10496293029149,
#                         "lng": -119.3109247197085
#                     },
#                     "southwest": {
#                         "lat": 47.10226496970849,
#                         "lng": -119.3136226802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Interstate Inn",
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116573536072994026277\">syneyed</a>"
#                     ],
#                     "photo_reference": "ATtYBwIUOmMeao8fh4Qc4H_3-9hCtIIn4VNeNq-LbglgaFsKf1iEmJaJlAv3dqoojoGDG94GLjsIpZnMdokSZYyuUOqXkhuWyd93BNYu6J0j6T8nMteoQgQBnCX28XsLKBcwHlLtciupa8PLA2sCX1OIEaxvrTHYuTZIv8cu3T00qLrCd7jl",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJOeqMWBE_mVQREqYUp6yr51M",
#             "plus_code": {
#                 "compound_code": "4M3Q+95 Moses Lake, WA, USA",
#                 "global_code": "85V24M3Q+95"
#             },
#             "rating": 3.1,
#             "reference": "ChIJOeqMWBE_mVQREqYUp6yr51M",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 69,
#             "vicinity": "2801 West Broadway Avenue, Moses Lake"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.10022,
#                     "lng": -119.24867
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.1015699802915,
#                         "lng": -119.2471827197085
#                     },
#                     "southwest": {
#                         "lat": 47.0988720197085,
#                         "lng": -119.2498806802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Inn at Moses Lake",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 636,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101746327416963931317\">Inn at Moses Lake</a>"
#                     ],
#                     "photo_reference": "ATtYBwIUFh06C5YuukDtScBdJTTukKEo7VR8g_v4OD4dCAArfacJBancu_SYIbc1StZeq7TK1S2FK-QMW-vD6kTAxGBZ35KdQ0hQ7pl5GJiVQ3fiwAMlkuNuCrOs3A0rZXrUNsuawBJvmqgXThQG3onkzAp6D8nEV_EuU0HYINtnTdw__ENW",
#                     "width": 960
#                 }
#             ],
#             "place_id": "ChIJVes_My85mVQRZpw7UJW9Txc",
#             "plus_code": {
#                 "compound_code": "4Q22+3G Moses Lake, WA, USA",
#                 "global_code": "85V24Q22+3G"
#             },
#             "rating": 4.5,
#             "reference": "ChIJVes_My85mVQRZpw7UJW9Txc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 198,
#             "vicinity": "1741 Kittelson Road, Moses Lake"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.1207885,
#                     "lng": -119.2681495
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.12217748029149,
#                         "lng": -119.2665026197085
#                     },
#                     "southwest": {
#                         "lat": 47.1194795197085,
#                         "lng": -119.2692005802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "name": "Coldwell Banker Tomlinson Ranch & Home",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 890,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110676500253328134695\">Coldwell Banker Tomlinson Ranch &amp; Home</a>"
#                     ],
#                     "photo_reference": "ATtYBwL0Oz1qga9RpkuMa1fe2PHvAfixxtcvjAbTR_d2u2aDxKpXwD7qTbRIo3gJRGYSgolFS2MvFqBBfHFn9ISq646SsTg0vNvJFemeZ_76Bbm2Hw2EKKfFoW0kPMyzaB0UXYiouOHyt5FFpNrh0TwBV0NEtOQaDOUK75K62ajFt5tQbeHr",
#                     "width": 1780
#                 }
#             ],
#             "place_id": "ChIJU1mG98c4mVQRNL7iLCDKaIs",
#             "plus_code": {
#                 "compound_code": "4PCJ+8P Moses Lake, WA, USA",
#                 "global_code": "85V24PCJ+8P"
#             },
#             "rating": 3,
#             "reference": "ChIJU1mG98c4mVQRNL7iLCDKaIs",
#             "scope": "GOOGLE",
#             "types": [
#                 "real_estate_agency",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 12,
#             "vicinity": "1000 South Pioneer Way, Moses Lake"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.1014031,
#                     "lng": -119.3127358
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.1029591802915,
#                         "lng": -119.3113444197085
#                     },
#                     "southwest": {
#                         "lat": 47.1002612197085,
#                         "lng": -119.3140423802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Motel Oasis",
#             "photos": [
#                 {
#                     "height": 3006,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113613121310464506178\">Suzanne Dickenson</a>"
#                     ],
#                     "photo_reference": "ATtYBwKiWzD5L2mzWeWy2jzeTGPKseMdGeMGEKh4kJqK-5wIRCcru8M4tvmyQOXKlE8F6-Dx47bXOUfNDTehQ-7sc6Ll0ZknkIsFdj7-IAhTSJiq0c96sFP5WwruKluTDmr2drsB9xCDsPbQ4Ij6jcD2bymyv4h3L72hSRbAbe_fNuMc3NaJ",
#                     "width": 5344
#                 }
#             ],
#             "place_id": "ChIJC1DHDRE_mVQRzMhMTy_gR6w",
#             "plus_code": {
#                 "compound_code": "4M2P+HW Moses Lake, WA, USA",
#                 "global_code": "85V24M2P+HW"
#             },
#             "rating": 4.2,
#             "reference": "ChIJC1DHDRE_mVQRzMhMTy_gR6w",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 211,
#             "vicinity": "466 Melva Lane, Moses Lake"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.1024328,
#                     "lng": -119.3123657
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.1037817802915,
#                         "lng": -119.3110167197085
#                     },
#                     "southwest": {
#                         "lat": 47.1010838197085,
#                         "lng": -119.3137146802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Quality Inn",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1920,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105363616661255977517\">Quality Inn</a>"
#                     ],
#                     "photo_reference": "ATtYBwKlpL32kVHW5X3QwuTbxvRSIQm1J2jokOAKjBinyNOVi-MPfftSZDQgYjKGDtcb6__aiRf7pAeSL-rfemw7uRyMsqCJy-dT_UkHHhJa_tZ3C_9PcQMSyz7kKHhRduSBrvrwMEZb1FjL5bJC9DcginchKcYvdE6p7p-TcsWqsILU8osR",
#                     "width": 2880
#                 }
#             ],
#             "place_id": "ChIJldzJbBE_mVQR2W2VujSStUk",
#             "plus_code": {
#                 "compound_code": "4M2Q+X3 Moses Lake, WA, USA",
#                 "global_code": "85V24M2Q+X3"
#             },
#             "rating": 3.4,
#             "reference": "ChIJldzJbBE_mVQR2W2VujSStUk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 327,
#             "vicinity": "449 Melva Lane, Moses Lake"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.145697,
#                     "lng": -119.2933559
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.14709508029149,
#                         "lng": -119.2920083697085
#                     },
#                     "southwest": {
#                         "lat": 47.14439711970849,
#                         "lng": -119.2947063302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png",
#             "name": "Moses Lake Christian School",
#             "place_id": "ChIJSXHMzVpHmVQRuxt3TZXDJmM",
#             "plus_code": {
#                 "compound_code": "4PW4+7M Moses Lake, WA, USA",
#                 "global_code": "85V24PW4+7M"
#             },
#             "reference": "ChIJSXHMzVpHmVQRuxt3TZXDJmM",
#             "scope": "GOOGLE",
#             "types": [
#                 "school",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Moses Lake"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.11189290000001,
#                     "lng": -119.2651197
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.11334998029151,
#                         "lng": -119.2636036697085
#                     },
#                     "southwest": {
#                         "lat": 47.11065201970851,
#                         "lng": -119.2663016302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png",
#             "name": "Moses Lake High School",
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107858846145471977988\">Dr. Joshua Meek</a>"
#                     ],
#                     "photo_reference": "ATtYBwICyUtteeG7RLWxjCKE0kttK_chB8EpYn0-JtkYzxk1wjp1pSAEoCvut4w1U_AcWS_lZsK6XIaQTAtlRMBOXWRRxrWPGQ6KQjkL3pnK3eGjywj4DZQMoCPuQu6qiPgXZnx8NXJdOq_rXtM2pBsU8GpytKs69iYYlzdn9zCD6iexicIH",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJK5SNP844mVQR4T_WQqeQIpU",
#             "plus_code": {
#                 "compound_code": "4P6M+QX Moses Lake, WA, USA",
#                 "global_code": "85V24P6M+QX"
#             },
#             "rating": 4,
#             "reference": "ChIJK5SNP844mVQR4T_WQqeQIpU",
#             "scope": "GOOGLE",
#             "types": [
#                 "secondary_school",
#                 "school",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 18,
#             "vicinity": "803 Sharon Avenue East, Moses Lake"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.1031883,
#                     "lng": -119.3175825
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.1044815302915,
#                         "lng": -119.3158933197085
#                     },
#                     "southwest": {
#                         "lat": 47.1017835697085,
#                         "lng": -119.3185912802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Best Western Plus Lake Front Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2034,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100511025304292097992\">Best Western Plus Lake Front Hotel</a>"
#                     ],
#                     "photo_reference": "ATtYBwIBGtCJfZlhB3cfk7qUmSIPpLriM7FOBri5l2TwwTtEa7oyCAMvqLhDb7_sJFkKqeineQiU4yIVeXF-Vz_owqnSk-syOrygVV8u34CYX83kjoCgsyLwwrlC5rbFgkH55Msso4fR1EDL3uuAy9ezhPDLb3YAa-8V4F_FpqyMk6QYvXB6",
#                     "width": 2879
#                 }
#             ],
#             "place_id": "ChIJt7GNFhI_mVQRqEk-J0Sx1rg",
#             "plus_code": {
#                 "compound_code": "4M3J+7X Moses Lake, WA, USA",
#                 "global_code": "85V24M3J+7X"
#             },
#             "rating": 4,
#             "reference": "ChIJt7GNFhI_mVQRqEk-J0Sx1rg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 835,
#             "vicinity": "3000 West Marina Drive, Moses Lake"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.1346155,
#                     "lng": -119.2725255
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.1358498802915,
#                         "lng": -119.2710508197085
#                     },
#                     "southwest": {
#                         "lat": 47.1331519197085,
#                         "lng": -119.2737487802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "NAPA Auto Parts - Lake Auto Parts",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 875,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114094875451535256432\">NAPA Auto Parts - Lake Auto Parts</a>"
#                     ],
#                     "photo_reference": "ATtYBwLa_et4aiLlERDy3o6Ka7lAcUUZBCZARsF0RT3PEhfyCand7jSCtNfH0WjAcCv8O_DNWxczoe3f-rlyAXpU6hYbJA3pAw8fQKepHTl_JWvijbrP3NP8N7GkZQqVEuQ_5X72FlMwJdjBiCDzR6-pB7oqEen2pj7EiJlvzBiFXoTCbSCV",
#                     "width": 1556
#                 }
#             ],
#             "place_id": "ChIJ1X6uwKM4mVQRLnhI84foBAs",
#             "plus_code": {
#                 "compound_code": "4PMG+RX Moses Lake, WA, USA",
#                 "global_code": "85V24PMG+RX"
#             },
#             "rating": 4.5,
#             "reference": "ChIJ1X6uwKM4mVQRLnhI84foBAs",
#             "scope": "GOOGLE",
#             "types": [
#                 "car_repair",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 48,
#             "vicinity": "610 East Broadway Avenue, Moses Lake"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.1127366,
#                     "lng": -119.2604829
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.1142254802915,
#                         "lng": -119.2588747197085
#                     },
#                     "southwest": {
#                         "lat": 47.1115275197085,
#                         "lng": -119.2615726802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "Subway",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113639447110956763718\">Donny Parker</a>"
#                     ],
#                     "photo_reference": "ATtYBwLGL-hp3qGIKaiD06vWdVjvwrr90Th6zxDsaefZGMucrSbOPVKNVEJjk_L7C9FiOQSsAclYXtm_jIbdog-wKTHzFJSjphYbgL8KZAUE1pArGpLzxVlkk7yeHobmubhRKOhHo5yBBwD2B5IlxiX2jKrHq7iCtxflVFggkD0Siohj_-eO",
#                     "width": 2220
#                 }
#             ],
#             "place_id": "ChIJh_GZ_M84mVQRDNhOLLOvFxI",
#             "plus_code": {
#                 "compound_code": "4P7Q+3R Moses Lake, WA, USA",
#                 "global_code": "85V24P7Q+3R"
#             },
#             "price_level": 1,
#             "rating": 4,
#             "reference": "ChIJh_GZ_M84mVQRDNhOLLOvFxI",
#             "scope": "GOOGLE",
#             "types": [
#                 "meal_takeaway",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 146,
#             "vicinity": "1520 South Pioneer Way, Moses Lake"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.1008286,
#                     "lng": -119.2485096
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.1021645302915,
#                         "lng": -119.2468325697085
#                     },
#                     "southwest": {
#                         "lat": 47.0994665697085,
#                         "lng": -119.2495305302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Wingate by Wyndham Moses Lake",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 400,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116841229623052432294\">Wingate by Wyndham Moses Lake</a>"
#                     ],
#                     "photo_reference": "ATtYBwIUIJrG3QjqrYPgrCJlzlf4zyZLk10-63oBwWVCkIjCYT-8TryjmiTugf9DFg_zyqKCkRZ2zsE--Hwhc8nRytPo09ySWhhINrrz026VlcTU7hVQ9fnYZFMCwfXsMg5WL02AQKFoTNtPW1-lMe_vx2BfGXuQvsnLSL6UYLjXgNxqHVgh",
#                     "width": 711
#                 }
#             ],
#             "place_id": "ChIJdQbtSS85mVQR0wom3B-_5A4",
#             "plus_code": {
#                 "compound_code": "4Q22+8H Moses Lake, WA, USA",
#                 "global_code": "85V24Q22+8H"
#             },
#             "rating": 4.4,
#             "reference": "ChIJdQbtSS85mVQR0wom3B-_5A4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 293,
#             "vicinity": "1735 Kittelson Road, Moses Lake"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.127146,
#                     "lng": -119.284871
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.1283673302915,
#                         "lng": -119.2833878697085
#                     },
#                     "southwest": {
#                         "lat": 47.1256693697085,
#                         "lng": -119.2860858302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "name": "Paramount Supply Co",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "place_id": "ChIJZQxH_604mVQRSnEQcdIkIrY",
#             "plus_code": {
#                 "compound_code": "4PG8+V3 Moses Lake, WA, USA",
#                 "global_code": "85V24PG8+V3"
#             },
#             "reference": "ChIJZQxH_604mVQRSnEQcdIkIrY",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "vicinity": "538 West 3rd Avenue, Moses Lake"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.102159,
#                     "lng": -119.250126
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.1035565802915,
#                         "lng": -119.2484756197085
#                     },
#                     "southwest": {
#                         "lat": 47.1008586197085,
#                         "lng": -119.2511735802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Comfort Suites Moses Lake",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1920,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107716756626654038023\">Comfort Suites Moses Lake</a>"
#                     ],
#                     "photo_reference": "ATtYBwI9lK355aPdzGSSd7t3BAk-yPRvhkwp20b_fGCTz6oJ5nVzvmylEuSytJfd7eIy4W6JJ0yZ3awOUZ17O76_Cid8cHaHBw9vRjxZ1JMVjfmfPaGdfCjVwQUxM9n9oe15dKpMXf62KZ--K8SPOjtPN_wh9Q8GlETbATsvEFbJ3SP14KAW",
#                     "width": 2880
#                 }
#             ],
#             "place_id": "ChIJt8bb9ig5mVQRODat8uVJ2z8",
#             "plus_code": {
#                 "compound_code": "4P2X+VW Moses Lake, WA, USA",
#                 "global_code": "85V24P2X+VW"
#             },
#             "rating": 4.4,
#             "reference": "ChIJt8bb9ig5mVQRODat8uVJ2z8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 298,
#             "vicinity": "1700 Kittelson Road, Moses Lake"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.13047950000001,
#                     "lng": -119.2708122
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.13189593029151,
#                         "lng": -119.2693210197085
#                     },
#                     "southwest": {
#                         "lat": 47.12919796970851,
#                         "lng": -119.2720189802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "name": "Rite Aid",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 5312,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110330108938413886575\">troy white</a>"
#                     ],
#                     "photo_reference": "ATtYBwLaDKHX8IucTxac0mpE4Mh21UIyB8IHjhiWumhULoVYY_H1R-U69U3nV0UhOdwxnTzw3_X7xL_nZcHByDYfp-syLFUAAjacukrq0PYUtEZNSDXyveFJzB-N7jqdozdzWm-TVzumTrlyLDSCNaAk5N8fFdO1kh0KTtvWEcWe0KAbCAU",
#                     "width": 2988
#                 }
#             ],
#             "place_id": "ChIJaQumVbs4mVQRJ5C_9qP9W90",
#             "plus_code": {
#                 "compound_code": "4PJH+5M Moses Lake, WA, USA",
#                 "global_code": "85V24PJH+5M"
#             },
#             "price_level": 2,
#             "rating": 2.6,
#             "reference": "ChIJaQumVbs4mVQRJ5C_9qP9W90",
#             "scope": "GOOGLE",
#             "types": [
#                 "drugstore",
#                 "convenience_store",
#                 "food",
#                 "health",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 34,
#             "vicinity": "500 South Pioneer Way, Moses Lake"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.1115493,
#                     "lng": -119.2658843
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.1131983302915,
#                         "lng": -119.2639856197085
#                     },
#                     "southwest": {
#                         "lat": 47.1105003697085,
#                         "lng": -119.2666835802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/worship_general-71.png",
#             "name": "Journey Moses Lake Church",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 366,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104299103994207461443\">Journey Moses Lake Church</a>"
#                     ],
#                     "photo_reference": "ATtYBwIykPyZRegLOkOLnJUUkHPwPOCVC5qZBGm_cZnMSs-r5OXim7bm0iOYtmFdd4HXehNnzlHL7X6aZTDs_XLLx1NWEve1fS8LVFghEhsqVALhBZ7RxXFC-QEBTAsAmhuwSRjbVJQex0UGjoPWwQlA3KAygk8SZ1-itO8fUFBI19VR1OWP",
#                     "width": 512
#                 }
#             ],
#             "place_id": "ChIJYfNN4-8-mVQRSBJaunJ9yMU",
#             "plus_code": {
#                 "compound_code": "4P6M+JJ Moses Lake, WA, USA",
#                 "global_code": "85V24P6M+JJ"
#             },
#             "rating": 5,
#             "reference": "ChIJYfNN4-8-mVQRSBJaunJ9yMU",
#             "scope": "GOOGLE",
#             "types": [
#                 "church",
#                 "place_of_worship",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3,
#             "vicinity": "803 Sharon Avenue East, Moses Lake"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 47.1992035,
#                     "lng": -119.312341
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.22080505431704,
#                         "lng": -119.2876180750641
#                     },
#                     "southwest": {
#                         "lat": 47.15662888140385,
#                         "lng": -119.351275951865
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png",
#             "name": "Moses Lake North",
#             "photos": [
#                 {
#                     "height": 2988,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/118282270108726691589\">Alisha Louise Merritt</a>"
#                     ],
#                     "photo_reference": "ATtYBwJVS7wKfM8NKt3rCfD6q8iLnvoqVSNoSBLnqIdHKYOnrMEcSgXBSg9F5YPPRqyyK_wF9z0EzaQrF7rRhWWcVRV1nC0z0WohdS64pGIz9TMtHsTZw4vhmvCdt4Aarq-vcGPLwQqpXGglH3XNQGcvkCRGsozqJSd0US8kDRd5TCowAssC",
#                     "width": 5312
#                 }
#             ],
#             "place_id": "ChIJWc_DxpNGmVQROw87qS6WrOw",
#             "reference": "ChIJWc_DxpNGmVQROw87qS6WrOw",
#             "scope": "GOOGLE",
#             "types": [
#                 "locality",
#                 "political"
#             ],
#             "vicinity": "Moses Lake North"
#         }
#     ],
#     "status": "OK"
# }

# %%
# Print the name and address of the first Hotel that appears
print(places_data["results"][1]["name"])
print(places_data["results"][1]["vicinity"])
# Out:
# Ramada by Wyndham Moses Lake
# 1745 Kittelson Road, Moses Lake

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
# Create bank symbol layer
bank_layer = gmaps.symbol_layer(
    locations, fill_color='rgba(0, 150, 0, 0.4)',
    stroke_color='rgba(0, 0, 150, 0.4)', scale=2,)


# Display figure
fig = gmaps.figure()
fig.add_layer(bank_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
