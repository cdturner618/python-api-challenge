# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 600

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

response_json = []

# %%
# Make a request for each of the cities
for city in cities:
    print(f"Processing Record: {city}")

    # Get one of the posts
    post_response = requests.get(url + str(city))

    # Save post's JSON
    response_json.append(post_response.json())
# Out:
# Processing Record: kapaa
# Processing Record: chokurdakh
# Processing Record: esperance
# Processing Record: taolanaro
# Processing Record: port blair
# Processing Record: ushuaia
# Processing Record: riyadh
# Processing Record: severo-kurilsk
# Processing Record: tuktoyaktuk
# Processing Record: baghdad
# Processing Record: albany
# Processing Record: saskylakh
# Processing Record: amderma
# Processing Record: basco
# Processing Record: meulaboh
# Processing Record: mahebourg
# Processing Record: jena
# Processing Record: belushya guba
# Processing Record: cayenne
# Processing Record: cape town
# Processing Record: port-gentil
# Processing Record: hovd
# Processing Record: punta arenas
# Processing Record: mezen
# Processing Record: ambunti
# Processing Record: xuddur
# Processing Record: dunedin
# Processing Record: ust-kamchatsk
# Processing Record: cabedelo
# Processing Record: vredendal
# Processing Record: krasnyy yar
# Processing Record: avarua
# Processing Record: tasiilaq
# ...

# %%
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | yerbogachen
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | touba
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | rio grande
# Processing Record 7 of Set 1 | ibra
# Processing Record 8 of Set 1 | port elizabeth
# Processing Record 9 of Set 1 | tuktoyaktuk
# Processing Record 10 of Set 1 | avarua
# Processing Record 11 of Set 1 | nemuro
# Processing Record 12 of Set 1 | morgan city
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | kawalu
# Processing Record 15 of Set 1 | hami
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | katsuura
# Processing Record 18 of Set 1 | hjallerup
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | bengkulu
# Processing Record 21 of Set 1 | victoria
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_df=pd.read_csv("../output_data/cities.csv")
city_df.head()
# Out:
#    City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  ostrovnoy           2      RU  1558378754        72  68.05
# 1        1  mahebourg          75      MU  1558378503        74 -20.41
# 2        2    qaanaaq          25      GL  1558378755        73  77.48
# 3        3     zhuhai           0      CN  1558378755        39  40.71
# 4        4  cape town          20      ZA  1558378755        76 -33.93
#
#       Lng  Max Temp  Wind Speed
# 0   39.51     37.50        7.16
# 1   57.70     78.80       11.41
# 2  -69.36     22.20        2.37
# 3  112.04     44.60        4.47
# 4   18.42     55.99        8.05

# %%
city_df[["Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Date"]].describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  548.000000  548.000000  548.000000  548.000000  548.000000  548.000000
# mean    19.665146   20.675529   64.970785   67.671533   49.405109    8.672682
# std     33.623560   90.307948   18.704318   23.697626   36.914201    5.865974
# min    -54.810000 -173.230000    4.920000    4.000000    0.000000    0.540000
# 25%     -6.267500  -61.015000   53.970000   52.000000   13.750000    4.680000
# 50%     21.390000   21.240000   64.990000   71.000000   46.500000    7.010000
# 75%     47.887500  102.937500   80.600000   86.000000   81.000000   11.410000
# max     78.220000  179.320000  104.100000  290.000000  100.000000   46.080000
#
#                Date
# count  5.480000e+02
# mean   1.558379e+09
# std    7.820486e+01
# min    1.558378e+09
# 25%    1.558379e+09
# 50%    1.558379e+09
# 75%    1.558379e+09
# max    1.558379e+09

# %%
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  599.000000  599.000000  599.000000  599.000000  599.000000  599.000000
# mean    19.877028   19.568998   69.794808   69.353923   51.569282    7.979416
# std     33.262944   91.418472   15.678452   22.704698   35.405602    5.660694
# min    -54.800000 -179.170000   12.200000    7.000000    0.000000    0.360000
# 25%     -8.540000  -61.210000   59.000000   55.000000   20.000000    3.620000
# 50%     24.370000   24.670000   73.110000   75.000000   59.000000    6.730000
# 75%     46.585000  102.255000   80.600000   87.000000   85.000000   11.050000
# max     78.220000  179.320000  116.600000  100.000000  100.000000   42.500000
#
#                Date
# count  5.990000e+02
# mean   1.593605e+09
# std    5.738815e+01
# min    1.593605e+09
# 25%    1.593605e+09
# 50%    1.593605e+09
# 75%    1.593605e+09
# max    1.593605e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_df.count()
# Out:
# City_ID       548
# City          548
# Cloudiness    548
# Country       544
# Date          548
# Humidity      548
# Lat           548
# Lng           548
# Max Temp      548
# Wind Speed    548
# dtype: int64

# %%
city_df.loc[city_df["Humidity"]>100, : ]
# Out:
#      City_ID   City  Cloudiness Country        Date  Humidity   Lat    Lng  \
# 129      129  paita           0      PE  1558378778       290 -5.09 -81.11
#
#      Max Temp  Wind Speed
# 129      62.6       17.22

# %%
city_df=city_df.loc[(city_df["Humidity"]<101)]
city_df.count()
# Out:
# City_ID       547
# City          547
# Cloudiness    547
# Country       543
# Date          547
# Humidity      547
# Lat           547
# Lng           547
# Max Temp      547
# Wind Speed    547
# dtype: int64

# %%
city_df.head()
# Out:
#    City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  ostrovnoy           2      RU  1558378754        72  68.05
# 1        1  mahebourg          75      MU  1558378503        74 -20.41
# 2        2    qaanaaq          25      GL  1558378755        73  77.48
# 3        3     zhuhai           0      CN  1558378755        39  40.71
# 4        4  cape town          20      ZA  1558378755        76 -33.93
#
#       Lng  Max Temp  Wind Speed
# 0   39.51     37.50        7.16
# 1   57.70     78.80       11.41
# 2  -69.36     22.20        2.37
# 3  112.04     44.60        4.47
# 4   18.42     55.99        8.05

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  550.000000  550.000000  550.000000  550.000000  550.000000  550.000000
# mean    19.973545   17.124400   58.331400   67.890909   52.141818    8.544800
# std     33.284840   91.595451   25.795297   20.864881   35.766469    6.078869
# min    -54.800000 -179.170000  -11.340000    9.000000    0.000000    0.160000
# 25%     -8.077500  -64.627500   42.800000   55.000000   20.000000    4.525000
# 50%     23.630000   19.635000   64.940000   72.000000   57.000000    7.325000
# 75%     48.672500   97.350000   78.800000   83.000000   86.750000   11.410000
# max     78.220000  179.320000  102.200000  100.000000  100.000000   46.080000
#
#                Date
# count  5.500000e+02
# mean   1.585764e+09
# std    5.539674e+01
# min    1.585764e+09
# 25%    1.585764e+09
# 50%    1.585764e+09
# 75%    1.585764e+09
# max    1.585764e+09

# %%
#  Get the indices of cities that have humidity over 100%.
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
Scatter= city_df[["Max Temp","Lat","Humidity","Cloudiness","Wind Speed"]]

x_values = Scatter["Lat"]
y_values = Scatter["Max Temp"]


plt.scatter(x_values,y_values, marker="o", facecolors="steelblue", edgecolors="black",alpha=0.75)
plt.title("City Latitude vs. max Temperature (02/26/2021)")
plt.xlabel('Latitude')
plt.ylabel('Max Tempurature (F)')
plt.savefig("../Images/Lat_vs_Temp.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_values = Scatter["Lat"]
y_values = Scatter["Humidity"]


plt.scatter(x_values,y_values, marker="o", facecolors="steelblue", edgecolors="black",alpha=0.75)
plt.title("City Latitude vs. Humidity (02/26/2021)")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.savefig("../Images/Lat_vs_Hum.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_values = Scatter["Lat"]
y_values = Scatter["Cloudiness"]


plt.scatter(x_values,y_values, marker="o", facecolors="steelblue", edgecolors="black",alpha=0.75)
plt.title("City Latitude vs. Cloudiness (02/26/2021)")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.savefig("../Images/Lat_vs_Cloud.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_values = Scatter["Lat"]
y_values = Scatter["Wind Speed"]


plt.scatter(x_values,y_values, marker="o", facecolors="steelblue", edgecolors="black",alpha=0.75)
plt.title("City Latitude vs. Wind Speed (02/26/2021)")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig("../Images/Lat_vs_Wind.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
Scatter= city_df[["Max Temp","Lat","Humidity","Cloudiness","Wind Speed"]]
northern=Scatter.loc[Scatter["Lat"]>0, : ]
x_values = northern["Lat"]
y_values = northern["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(25,22),fontsize=15,color="red")

plt.scatter(x_values,y_values, marker="o", facecolors="steelblue", edgecolors="black",alpha=0.75)
plt.title("City Latitude vs. max Temperature (02/26/2021)")
plt.xlabel('Latitude')
plt.ylabel('Max Tempurature (F)')
print(f"The r-squared is: {rvalue**2}")
plt.savefig("../Images/LatNorth_vs_Temp2.png")
plt.show()
# Out:
# The r-squared is: 0.6644951847801386

# %%
# Out:
# The r-value is: 0.46937863826630627

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
Scatter= city_df[["Max Temp","Lat","Humidity","Cloudiness","Wind Speed"]]
southern=Scatter.loc[Scatter["Lat"]<0, : ]
x_values = southern["Lat"]
y_values = southern["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,70),fontsize=15,color="red")

plt.scatter(x_values,y_values, marker="o", facecolors="green", edgecolors="black",alpha=0.75)
plt.title("City Latitude vs. max Temperature (02/26/2021)")
plt.xlabel('Latitude')
plt.ylabel('Max Tempurature (F)')
print(f"The r-squared is: {rvalue**2}")
plt.savefig("../Images/LatSouth_vs_Temp2.png")
plt.show()
# Out:
# The r-squared is: 0.5880057276369802

# %%
# Out:
# The r-value is: 0.6082708688906918

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
Scatter= city_df[["Max Temp","Lat","Humidity","Cloudiness","Wind Speed"]]
northern=Scatter.loc[Scatter["Lat"]>0, : ]
x_values = northern["Lat"]
y_values = northern["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,15),fontsize=15,color="red")

plt.scatter(x_values,y_values, marker="o", facecolors="steelblue", edgecolors="black",alpha=0.75)
plt.title("City Latitude vs. Humidity (02/26/2021)")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print(f"The r-squared is: {rvalue**2}")
plt.savefig("../Images/LatNorth_vs_Hum2.png")
plt.show()
# Out:
# The r-squared is: 0.010729512501511098

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
Scatter= city_df[["Max Temp","Lat","Humidity","Cloudiness","Wind Speed"]]
southern=Scatter.loc[Scatter["Lat"]<0, : ]
x_values = southern["Lat"]
y_values = southern["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,25),fontsize=15,color="red")

plt.scatter(x_values,y_values, marker="o", facecolors="green", edgecolors="black",alpha=0.75)
plt.title("City Latitude vs. Humidity (02/26/2021)")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print(f"The r-squared is: {rvalue**2}")
plt.savefig("../Images/LatSouth_vs_Hum2.png")
plt.show()
# Out:
# The r-squared is: 0.01299355637910035

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
Scatter= city_df[["Max Temp","Lat","Humidity","Cloudiness","Wind Speed"]]
northern=Scatter.loc[Scatter["Lat"]>0, : ]
x_values = northern["Lat"]
y_values = northern["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,60),fontsize=15,color="red")

plt.scatter(x_values,y_values, marker="o", facecolors="steelblue", edgecolors="black",alpha=0.75)
plt.title("City Latitude vs. Cloudiness (02/26/2021)")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
print(f"The r-squared is: {rvalue**2}")
plt.savefig("../Images/LatNorth_vs_Cloud2.png")
plt.show()
# Out:
# The r-squared is: 0.007627485925231671

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
Scatter= city_df[["Max Temp","Lat","Humidity","Cloudiness","Wind Speed"]]
southern=Scatter.loc[Scatter["Lat"]<0, : ]
x_values = southern["Lat"]
y_values = southern["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,25),fontsize=15,color="red")

plt.scatter(x_values,y_values, marker="o", facecolors="green", edgecolors="black",alpha=0.75)
plt.title("City Latitude vs. Cloudiness (02/26/2021)")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
print(f"The r-squared is: {rvalue**2}")
plt.savefig("../Images/LatSouth_vs_Cloud2.png")
plt.show()
# Out:
# The r-squared is: 0.05294530205984339

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
Scatter= city_df[["Max Temp","Lat","Humidity","Cloudiness","Wind Speed"]]
northern=Scatter.loc[Scatter["Lat"]>0, : ]
x_values = northern["Lat"]
y_values = northern["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,25),fontsize=15,color="red")

plt.scatter(x_values,y_values, marker="o", facecolors="steelblue", edgecolors="black",alpha=0.75)
plt.title("City Latitude vs. Wind Speed (02/26/2021)")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
print(f"The r-squared is: {rvalue**2}")
plt.savefig("../Images/LatNorth_vs_Wind2.png")
plt.show()
# Out:
# The r-squared is: 0.011478610492563561

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
Scatter= city_df[["Max Temp","Lat","Humidity","Cloudiness","Wind Speed"]]
southern=Scatter.loc[Scatter["Lat"]<0, : ]
x_values = southern["Lat"]
y_values = southern["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,25),fontsize=15,color="red")

plt.scatter(x_values,y_values, marker="o", facecolors="green", edgecolors="black",alpha=0.75)
plt.title("City Latitude vs.Wind Speed (02/26/2021)")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
print(f"The r-squared is: {rvalue**2}")
plt.savefig("../Images/LatSouth_vs_Wind2.png")
plt.show()
# Out:
# The r-squared is: 0.11293389416296586

# %%
#Observable Trends
#1. The max tempature is higher in the southern hemisphere
#2. Wind Speed is the same across the north and southern hemisphere
#3. There is no correlationship between Latitude and Clouidness
#4. Wind speed is faster in the Northern Hemispher than in the Southern
